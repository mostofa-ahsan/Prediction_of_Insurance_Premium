# %%
import pandas as pd
df = pd.read_csv('C:/Users/mosto/REPOSITORY/Prediction_of_Insurance_Premium/data/auto_insurance_data.csv')
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
pd.options.display.max_columns=999

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
df.shape
# Out:
# (9134, 24)

# %%
from pandas_profiling import ProfileReport

# %%
df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
df['Activation_date'] = pd.to_datetime(df['Effective To Date'], infer_datetime_format = True)

# %%
df.dtypes
# Out:
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                        object
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                   int64
# Months Since Policy Inception             int64
# Number of Open Complaints                 int64
# Number of Policies                        int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# ...

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
df = df.drop(columns=['Customer','Effective To Date'])

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage Education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   EmploymentStatus Gender  Income Location Code Marital Status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage Education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   EmploymentStatus Gender  Income Location Code Marital Status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
df['Coverage'].value_counts()
# Out:
# Basic       5568
# Extended    2742
# Premium      824
# Name: Coverage, dtype: int64

# %%
coverage_dictionary = [{'col': 'Coverage','mapping':{"Basic":1, "Extended":2, "Premium": 3}}]

# %%
import category_encoders as ce

coverage_encoder = ce.OrdinalEncoder(cols = 'Coverage', mapping=coverage_dictionary)
df = coverage_encoder.fit_transform(df)

df['Coverage'].value_counts()
# Out:
# 1    5568
# 2    2742
# 3     824
# Name: Coverage, dtype: int64

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage Education  \
# 0  Washington              2763.519279       No         1  Bachelor
# 1     Arizona              6979.535903       No         2  Bachelor
# 2      Nevada             12887.431650       No         3  Bachelor
# 3  California              7645.861827       No         1  Bachelor
# 4  Washington              2813.692575       No         1  Bachelor
#
#   EmploymentStatus Gender  Income Location Code Marital Status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
df['Coverage'].describe()
# Out:
# count    9134.000000
# mean        1.480622
# std         0.655817
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: Coverage, dtype: float64

# %%
df['Education'].value_counts()
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
df['Education'] = df['Education'].replace({'College':'Bachelor'})

# %%
df['Education'].value_counts()
# Out:
# Bachelor                5429
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
education_dictionary = [{'col': 'Education','mapping':{"High School or Below":1, 
                                                       "Bachelor":2, "Master": 3,
                                                      "Doctor": 4}}]

education_encoder = ce.OrdinalEncoder(cols='Education', mapping=education_dictionary)

df = education_encoder.fit_transform(df)

df['Education'].value_counts()
# Out:
# 2    5429
# 1    2622
# 3     741
# 4     342
# Name: Education, dtype: int64

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington              2763.519279       No         1          2
# 1     Arizona              6979.535903       No         2          2
# 2      Nevada             12887.431650       No         3          2
# 3  California              7645.861827       No         1          2
# 4  Washington              2813.692575       No         1          2
#
#   EmploymentStatus Gender  Income Location Code Marital Status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
df = df.round({"Customer Lifetime Value": 2, "Total Claim Amount": 2})

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#   EmploymentStatus Gender  Income Location Code Marital Status  \
# 0         Employed      F   56274      Suburban        Married
# 1       Unemployed      F       0      Suburban         Single
# 2         Employed      F   48767      Suburban        Married
# 3       Unemployed      M       0      Suburban        Married
# 4         Employed      M   43836         Rural         Single
#
#    Monthly Premium Auto  Months Since Last Claim  \
# 0                    69                       32
# 1                    94                       13
# ...

# %%
df["EmploymentStatus"].describe()
# Out:
# count         9134
# unique           5
# top       Employed
# freq          5698
# Name: EmploymentStatus, dtype: object

# %%
df["EmploymentStatus"].value_counts()
# Out:
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: EmploymentStatus, dtype: int64

# %%
employment_encoder = ce.OneHotEncoder(cols="EmploymentStatus", use_cat_names = True)

df = employment_encoder.fit_transform(df)

df.head()
# Out:
# C:\Users\mosto\anaconda3\envs\RTX-2080\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    EmploymentStatus_Employed  EmploymentStatus_Unemployed  \
# 0                          1                            0
# 1                          0                            1
# 2                          1                            0
# 3                          0                            1
# ...

# %%
df.shape
# Out:
# (9134, 27)

# %%
df = df.rename(columns = {"EmploymentStatus_Employed": "Employed", "EmploymentStatus_Unemployed": "Unemployed",
                                      "EmploymentStatus_Disabled": "Disabled", "EmploymentStatus_Retired": "Retired",
                                      "EmploymentStatus_Medical Leave": "Medical_Leave"})

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired Gender  Income  \
# 0         1           0              0         0        0      F   56274
# 1         0           1              0         0        0      F       0
# 2         1           0              0         0        0      F   48767
# 3         0           1              0         0        0      M       0
# 4         1           0              0         0        0      M   43836
#
#   Location Code Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
df['Gender'].value_counts()
# Out:
# F    4658
# M    4476
# Name: Gender, dtype: int64

# %%
gender_encoder = ce.OneHotEncoder(cols = "Gender", use_cat_names=True)

df = gender_encoder.fit_transform(df)
# Out:
# C:\Users\mosto\anaconda3\envs\RTX-2080\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Gender_F  Gender_M  \
# 0         1           0              0         0        0         1         0
# 1         0           1              0         0        0         1         0
# 2         1           0              0         0        0         1         0
# 3         0           1              0         0        0         0         1
# 4         1           0              0         0        0         0         1
#
#    Income Location Code Marital Status  Monthly Premium Auto  \
# ...

# %%
df = df.rename(columns = {"Gender_M": "Male", "Gender_F": "Female"})

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Female  Male  \
# 0         1           0              0         0        0       1     0
# 1         0           1              0         0        0       1     0
# 2         1           0              0         0        0       1     0
# 3         0           1              0         0        0       0     1
# 4         1           0              0         0        0       0     1
#
#    Income Location Code Marital Status  Monthly Premium Auto  \
# ...

# %%
df["Location Code"].describe()
# Out:
# count         9134
# unique           3
# top       Suburban
# freq          5779
# Name: Location Code, dtype: object

# %%
df["Location Code"].value_counts()
# Out:
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: Location Code, dtype: int64

# %%
location_encoder = ce.OneHotEncoder(cols = "Location Code", use_cat_names=True)

df = location_encoder.fit_transform(df)

df.head()
# Out:
# C:\Users\mosto\anaconda3\envs\RTX-2080\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Female  Male  \
# 0         1           0              0         0        0       1     0
# 1         0           1              0         0        0       1     0
# 2         1           0              0         0        0       1     0
# ...

# %%
df = df.rename(columns = {"Location Code_Urban": "Urban", "Location Code_Rural": "Rural", 
                                                "Location Code_Suburban":"Suburban"})

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Female  Male  \
# 0         1           0              0         0        0       1     0
# 1         0           1              0         0        0       1     0
# 2         1           0              0         0        0       1     0
# 3         0           1              0         0        0       0     1
# 4         1           0              0         0        0       0     1
#
#    Income  Suburban  Rural  Urban Marital Status  Monthly Premium Auto  \
# ...

# %%
df['Vehicle Size'].value_counts()
# Out:
# Medsize    6424
# Small      1764
# Large       946
# Name: Vehicle Size, dtype: int64

# %%
vehicle_dictionary = [{'col': 'Vehicle Size','mapping':{"Small":1, 
                                                       "Medsize":2, "Large": 3}}]

vehicle_encoder = ce.OrdinalEncoder(cols="Vehicle Size", mapping=vehicle_dictionary)

df = vehicle_encoder.fit_transform(df)

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Female  Male  \
# 0         1           0              0         0        0       1     0
# 1         0           1              0         0        0       1     0
# 2         1           0              0         0        0       1     0
# 3         0           1              0         0        0       0     1
# 4         1           0              0         0        0       0     1
#
#    Income  Suburban  Rural  Urban Marital Status  Monthly Premium Auto  \
# ...

# %%
df.shape
# Out:
# (9134, 30)

# %%
columns_to_encode = ["Marital Status", "Policy Type", "Policy", "Sales Channel", "Vehicle Class"]
columns_encoder = ce.OneHotEncoder(cols = columns_to_encode, use_cat_names=True)

df = columns_encoder.fit_transform(df)
# Out:
# C:\Users\mosto\anaconda3\envs\RTX-2080\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df = df.rename(columns = {"Marital Status_Married": "Married", 
                                     "Marital Status_Divorced":"Divorced",
                                     "Marital Status_Single": "Single",
                                     "Policy Type_Personal Auto": "Personal Auto",
                                     "Policy Type_Corporate Auto": "Corporate Auto",
                                     "Policy Type_Special Auto": "Special Auto",
                                     "Policy_Personal L3": "Personal L3", 
                                     "Policy_Corporate L3": "Corporate L3",
                                     "Policy_Corporate L2": "Corporate L2",
                                     "Policy_Corporate L1": "Corporate L1",
                                     "Policy_Personal L2": "Personal L2",
                                     "Policy_Personal L1": "Personal L1",
                                     "Policy_Special L1": "Special L1",
                                     "Policy_Special L2": "Special L2",
                                     "Policy_Special L3": "Special L3",
                                     "Sales Channel_Call Center": "Call Center",
                                     "Sales Channel_Agent": "Agent",
                                     "Sales Channel_Web": "Web",
                                     "Sales Channel_Branch": "Branch",
                                     "Vehicle Class_Two-Door Car": "Two Door",
                                     "Vehicle Class_SUV": "SUV",
                                     "Vehicle Class_Sports Car": "Sports Car",
                                     "Vehicle Class_Four-Door Car": "Four Door",
                                     "Vehicle Class_Luxury SUV": "Luxury SUV",
                                     "Vehicle Class_Luxury Car": "Luxury Car"})

# %%
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage  Education  \
# 0  Washington                  2763.52       No         1          2
# 1     Arizona                  6979.54       No         2          2
# 2      Nevada                 12887.43       No         3          2
# 3  California                  7645.86       No         1          2
# 4  Washington                  2813.69       No         1          2
#
#    Employed  Unemployed  Medical_Leave  Disabled  Retired  Female  Male  \
# 0         1           0              0         0        0       1     0
# 1         0           1              0         0        0       1     0
# 2         1           0              0         0        0       1     0
# 3         0           1              0         0        0       0     1
# 4         1           0              0         0        0       0     1
#
#    Income  Suburban  Rural  Urban  Married  Single  Divorced  \
# ...

# %%
df.shape
# Out:
# (9134, 50)

# %%
df['State'].describe()
# Out:
# count           9134
# unique             5
# top       California
# freq            3150
# Name: State, dtype: object

# %%
df['State'].value_counts()
# Out:
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: State, dtype: int64

# %%
state_encoder = ce.OneHotEncoder(cols="State", use_cat_names=True)

df =state_encoder.fit_transform(df)


df = df.rename(columns = {"State_Arizona":"Arizona", 
                                     "State_Oregon": "Oregon",
                                     "State_California": "California",
                                     "State_Nevada": "Nevada",
                                     "State_Washington": "Washington"})
# Out:
# C:\Users\mosto\anaconda3\envs\RTX-2080\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
df.shape
# Out:
# (9134, 54)

# %%
df.head()
# Out:
#    Washington  Arizona  Nevada  California  Oregon  Customer Lifetime Value  \
# 0           1        0       0           0       0                  2763.52
# 1           0        1       0           0       0                  6979.54
# 2           0        0       1           0       0                 12887.43
# 3           0        0       0           1       0                  7645.86
# 4           1        0       0           0       0                  2813.69
#
#   Response  Coverage  Education  Employed  Unemployed  Medical_Leave  \
# 0       No         1          2         1           0              0
# 1       No         2          2         0           1              0
# 2       No         3          2         1           0              0
# 3       No         1          2         0           1              0
# 4       No         1          2         1           0              0
#
#    Disabled  Retired  Female  Male  Income  Suburban  Rural  Urban  Married  \
# ...

# %%
from sklearn.model_selection import train_test_split


#Split into Train and Test dataset
train, test = train_test_split(df, train_size= .80 , test_size = .20, random_state=42)



#Split into Train and Validation dataset

train , val = train_test_split(train, train_size=.85, test_size=.15, random_state=42)

# %%
print('Entire dataset dimesion: %d X %d' %(df.shape[0],df.shape[1]))


print('Training dataset dimesion: %d X %d' %(train.shape[0],train.shape[1]))

print('Testing dataset dimesion: %d X %d' %(test.shape[0],test.shape[1]))

print('Validation dataset dimesion: %d X %d' %(val.shape[0],val.shape[1]))
# Out:
# Entire dataset dimesion: 9134 X 54
# Training dataset dimesion: 6210 X 54
# Testing dataset dimesion: 1827 X 54
# Validation dataset dimesion: 1097 X 54

# %%
df.to_csv('C:/Users/mosto/REPOSITORY/Prediction_of_Insurance_Premium/data/cleaned_data.csv', index=  False)

# %%
train.to_csv('C:/Users/mosto/REPOSITORY/Prediction_of_Insurance_Premium/data/Train.csv', index=  False)
test.to_csv('C:/Users/mosto/REPOSITORY/Prediction_of_Insurance_Premium/data/Test.csv', index=  False)
val.to_csv('C:/Users/mosto/REPOSITORY/Prediction_of_Insurance_Premium/data/Validation.csv', index=  False)

# %%
train.head()
# Out:
#       Washington  Arizona  Nevada  California  Oregon  \
# 8216           0        0       0           1       0
# 8865           0        0       0           1       0
# 5401           0        0       0           0       1
# 383            0        1       0           0       0
# 1096           0        0       1           0       0
#
#       Customer Lifetime Value Response  Coverage  Education  Employed  \
# 8216                  7659.72       No         1          1         0
# 8865                  4836.75       No         2          2         0
# 5401                  2648.47       No         1          1         0
# 383                  13575.68       No         1          2         1
# 1096                  3494.15       No         2          1         1
#
#       Unemployed  Medical_Leave  Disabled  Retired  Female  Male  Income  \
# 8216           1              0         0        0       0     1       0
# ...

# %%
train.shape
# Out:
# (6210, 54)
